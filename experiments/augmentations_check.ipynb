# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('../')
from data_processing.augmentations import DataAug
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
ds, ds_info = tfds.load('cifar10', split='train', with_info=True)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Completed...:   0%|          | 0/1 [00:00<?, ? url/s]
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Size...: 0 MiB [00:09, ? MiB/s]
# Dl Completed...:   0%|          | 0/1 [00:09<?, ? url/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-bd3f5565b851> in <module>
# ----> 1 ds, ds_info = tfds.load('cifar10', split='train', with_info=True)
#
# ~/.pyenv/versions/new_ml_stuff/lib/python3.8/site-packages/tensorflow_datasets/core/load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     326   if download:
#     327     download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 328     dbuilder.download_and_prepare(**download_and_prepare_kwargs)
# ...

# %%
import numpy as np

layer=DataAug(96, 96)

for datapoint in ds.take(3):
    # print(datapoint['image'])
    aug = layer(datapoint['image']/255, training=True)
    plt.figure()
    plt.imshow(datapoint['image'])
    plt.figure()
    plt.imshow((aug.numpy()))
