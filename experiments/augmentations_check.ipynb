# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('../')
from data_processing.augmentations import RandomCropByol
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
ds, ds_info = tfds.load('stl10', split='unlabelled', with_info=True)

# %%
import numpy as np

layer=RandomCropByol(96, 96)

for datapoint in ds.take(3):
    # print(datapoint['image'])
    aug = layer(datapoint['image'], training=True)
    plt.figure()
    plt.imshow(datapoint['image'])
    plt.figure()
    plt.imshow((aug.numpy() / 255 ))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 240.40202
# 265.07928
# 215.06134
