# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('../')
import tensorflow as tf
import tensorflow_datasets as tfds
from data_processing.stl10 import get_stl10
from data_processing.cifar10 import get_cifar10
import data_processing.augmentations as augm

# %%
import importlib
importlib.reload(augm)
import numpy as np


ds, _ = get_cifar10(batch_size=5, split='train')
layer = augm.DataAugSmall(batch_size=5)

for x in ds.take(3):
    # print(datapoint['image'])
    aug = layer(x, training=True)
    # aug = tf.repeat(tf.image.rgb_to_grayscale(aug), 3, axis=-1)
    print(tf.shape(aug))
    plt.figure()
    plt.imshow(x[0])
    plt.figure()
    plt.imshow((aug[0].numpy()))

print((aug[0].numpy()))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tf.Tensor([ 5 32 32  3], shape=(4,), dtype=int32)
# tf.Tensor([ 5 32 32  3], shape=(4,), dtype=int32)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tf.Tensor([ 5 32 32  3], shape=(4,), dtype=int32)
# [[[-7.1324265e-01 -6.0329664e-01 -9.1432929e-02]
#   [-1.0403740e+00 -8.1288034e-01 -2.4403936e-01]
#   [-8.2845902e-01 -3.6265677e-01  3.9069271e-01]
#   ...
#   [ 4.9626568e-01  9.6844411e-01  1.7122483e+00]
#   [ 5.6388938e-01  9.0656173e-01  1.6178987e+00]
#   [ 5.7614917e-01  8.2397074e-01  1.5212449e+00]]
#
#  [[-7.1877062e-01 -4.7067627e-01  5.5482727e-04]
#   [-8.6889374e-01 -5.1191527e-01  3.6815800e-02]
#   [-7.0702392e-01 -1.8932337e-01  4.8987573e-01]
#   ...
#   [ 6.3705671e-01  1.0689324e+00  1.7736607e+00]
#   [ 6.2962186e-01  9.6196204e-01  1.6764295e+00]
#   [ 6.1381352e-01  8.8297093e-01  1.5797755e+00]]
#
#  [[-6.4675903e-01 -3.1894988e-01  1.4884777e-01]
#   [-6.1277658e-01 -1.6980599e-01  4.4714248e-01]
#   [-5.8410770e-01 -2.3081854e-02  6.8153936e-01]
#   ...
#   [ 8.0530000e-01  8.5633481e-01  1.2765625e+00]
#   [ 7.9761213e-01  9.5915490e-01  1.5123750e+00]
#   [ 7.2846454e-01  9.8523086e-01  1.6667187e+00]]
#
#  ...
#
#  [[ 2.1725791e-02  4.7952596e-02  1.4602886e-01]
#   [-2.2486140e-01 -1.8498260e-01 -5.0850175e-02]
#   [-3.8585714e-01 -3.4467044e-01 -2.0202534e-01]
#   ...
#   [-2.9088718e-01 -4.8715648e-01 -2.7163571e-01]
#   [-3.2436860e-01 -6.8541384e-01 -5.1065803e-01]
#   [-3.5598513e-01 -9.3198711e-01 -7.8708971e-01]]
#
#  [[-2.9281852e-01 -2.7116632e-01 -1.6999348e-01]
#   [ 2.0185880e-01  2.4794352e-01  3.5970452e-01]
#   [ 8.9425825e-02  1.3752517e-01  2.8600591e-01]
#   ...
#   [ 7.4635446e-03 -1.1707306e-01  8.9173734e-02]
#   [-1.3767464e-01 -2.3478536e-01 -1.5093467e-02]
#   [-2.8231519e-01 -4.1840595e-01 -1.9844283e-01]]
#
#  [[-5.1769817e-01 -4.9931654e-01 -3.9632758e-01]
#   [-3.0702743e-01 -2.6834378e-01 -1.5128252e-01]
#   [ 1.0361426e-01  1.5191966e-01  2.8464597e-01]
#   ...
#   [-1.8836629e-01 -2.3626038e-01 -6.6310905e-02]
#   [-2.3333716e-01 -1.6545551e-01  3.8330235e-02]
#   [-2.9893616e-01 -1.3577917e-01  8.2490601e-02]]]
