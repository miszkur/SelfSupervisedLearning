# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('../')
from data_processing.augmentations import DataAug, DataAugCifar10
import tensorflow as tf
import tensorflow_datasets as tfds
from data_processing.stl10 import get_stl10
from data_processing.cifar10 import get_cifar10

# %%
import numpy as np


ds, _ = get_cifar10(batch_size=5, split='train')
layer=DataAugCifar10(96, 96)

for x in ds.take(3):
    # print(datapoint['image'])
    aug = layer(x, training=True, batch_size=5)
    aug = tf.repeat(tf.image.rgb_to_grayscale(aug), 3, axis=-1)
    print(tf.shape(aug))
    plt.figure()
    plt.imshow(x[0])
    plt.figure()
    plt.imshow((aug[0].numpy()))

print((aug[0].numpy()))
# Out:
# tf.Tensor([  5 224 224   3], shape=(4,), dtype=int32)
# tf.Tensor([  5 224 224   3], shape=(4,), dtype=int32)
# tf.Tensor([  5 224 224   3], shape=(4,), dtype=int32)
# [[[0.97502977 0.97502977 0.97502977]
#   [0.9751001  0.9751001  0.9751001 ]
#   [0.9752583  0.9752583  0.9752583 ]
#   ...
#   [0.985891   0.985891   0.985891  ]
#   [0.9858892  0.9858892  0.9858892 ]
#   [0.9858884  0.9858884  0.9858884 ]]
#
#  [[0.9751267  0.9751267  0.9751267 ]
#   [0.97519904 0.97519904 0.97519904]
#   [0.97536165 0.97536165 0.97536165]
#   ...
#   [0.98603714 0.98603714 0.98603714]
#   [0.98603386 0.98603386 0.98603386]
#   [0.9860323  0.9860323  0.9860323 ]]
#
#  [[0.97535187 0.97535187 0.97535187]
#   [0.9754293  0.9754293  0.9754293 ]
#   [0.9756035  0.9756035  0.9756035 ]
#   ...
#   [0.98637134 0.98637134 0.98637134]
#   [0.9863638  0.9863638  0.9863638 ]
#   [0.98636025 0.98636025 0.98636025]]
#
#  ...
#
#  [[0.889664   0.889664   0.889664  ]
#   [0.8910291  0.8910291  0.8910291 ]
#   [0.8941032  0.8941032  0.8941032 ]
#   ...
#   [0.9294627  0.9294627  0.9294627 ]
#   [0.9305624  0.9305624  0.9305624 ]
#   [0.9310506  0.9310506  0.9310506 ]]
#
#  [[0.8877846  0.8877846  0.8877846 ]
#   [0.8891742  0.8891742  0.8891742 ]
#   [0.8923033  0.8923033  0.8923033 ]
#   ...
#   [0.9294253  0.9294253  0.9294253 ]
#   [0.9304748  0.9304748  0.9304748 ]
#   [0.9309409  0.9309409  0.9309409 ]]
#
#  [[0.8869541  0.8869541  0.8869541 ]
#   [0.8883546  0.8883546  0.8883546 ]
#   [0.89150804 0.89150804 0.89150804]
#   ...
#   [0.9294087  0.9294087  0.9294087 ]
#   [0.93043625 0.93043625 0.93043625]
#   [0.93089247 0.93089247 0.93089247]]]
