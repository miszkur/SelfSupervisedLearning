# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
# Dataset path: Users/username/tensorflow_datasets/stl10/1.0.0
ds, ds_info = tfds.load('stl10', split='train', with_info=True)

# %%
tfds.show_examples(ds, ds_info)

# %%
visible_devices = tf.config.get_visible_devices()
for devices in visible_devices:
  print(devices)
# Out:
# PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')

# %%
import matplotlib.pyplot as plt
imgs = []
labels = []
for row in ds.take(100):
    img = tf.image.resize(row['image'] / 255, [224, 224])
    imgs.append(img)
    labels.append(row['label'])
    # plt.imshow(img)
    # plt.figure()
    # print(row['label'])
# ds_batched = ds.batch(10)
# ds_batched['image']

# %%
import sys
sys.path.append('../')
from models.model import DirectPred
import numpy as np
dp = DirectPred(10)
dp.compile()
dp.train(X=np.array(imgs), y=np.array(labels), training_samples=len(imgs), epochs=10)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 13s 3s/step - loss: 2.5726
# Epoch 2/10
# 4/4 [==============================] - 12s 4s/step - loss: 2.2124
# Epoch 3/10
# 4/4 [==============================] - 10s 2s/step - loss: 2.0310
# Epoch 4/10
# 4/4 [==============================] - 10s 2s/step - loss: 1.7785
# Epoch 5/10
# 4/4 [==============================] - 10s 2s/step - loss: 1.7637
# Epoch 6/10
# 4/4 [==============================] - 11s 3s/step - loss: 1.5405
# Epoch 7/10
# 4/4 [==============================] - 8s 3s/step - loss: 1.3764
# Epoch 8/10
# 4/4 [==============================] - 12s 3s/step - loss: 1.0761
# Epoch 9/10
# 4/4 [==============================] - 12s 2s/step - loss: 1.1591
# Epoch 10/10
# 4/4 [==============================] - 12s 3s/step - loss: 1.0362
