# %%
import tensorflow as tf
import sys
sys.path.append('../')
sys.path.append('../..')
import experiment_utils as eu
import config as conf
import importlib
from data_processing.cifar10 import get_cifar10

# %%
importlib.reload(eu)

config = conf.get_eigenspace_experiment()
ds, _ = get_cifar10(batch_size=config.batch_size, split='train')
ds_small = ds.take(5)
experiment = eu.Experiment(config=config)
experiment.train(ds_small, 'saved_model', epochs=3)
# Out:
# 100%|██████████| 5/5 [00:13<00:00,  2.71s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 000: Loss: -0.200
# 100%|██████████| 5/5 [00:12<00:00,  2.41s/it]
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 001: Loss: -0.834
#  40%|████      | 2/5 [00:10<00:15,  5.14s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-42cc0074a4a8> in <module>
#       6 ds_small = ds.take(5)
#       7 experiment = eu.Experiment(config=config)
# ----> 8 experiment.train(ds_small, 'saved_model', epochs=3)
#
# ~/Documents/KTH/S3/Advanced DL/project/SelfSupervisedLearning/experiments/experiment_utils.py in train(self, ds, save_path, epochs, show_history)
#     118                 x_aug1 = self.data_aug(x)
#     119                 x_aug2 = self.data_aug(x)
# --> 120                 loss_value, h1, h2 = self.grad(x_aug1, x_aug2)
#     121
#     122                 # Update target network
#
# ~/Documents/KTH/S3/Advanced DL/project/SelfSupervisedLearning/experiments/experiment_utils.py in grad(self, input_aug1, input_aug2)
#      78             y_aug = tf.stop_gradient(y_aug)
#      79             loss_value = self.online_network.loss(x, x_aug, y, y_aug)
# ---> 80         grads = tape.gradient(
#      81             loss_value, self.online_network.model.trainable_variables)
#      82         self.online_network.model.optimizer.apply_gradients(
#
# ~/.pyenv/versions/new_ml_stuff/lib/python3.8/site-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1082                           for x in nest.flatten(output_gradients)]
#    1083
# -> 1084     flat_grad = imperative_grad.imperative_grad(
#    1085         self._tape,
#    1086         flat_targets,
#
# ~/.pyenv/versions/new_ml_stuff/lib/python3.8/site-packages/tensorflow/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      69         "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
#      70
# ---> 71   return pywrap_tfe.TFE_Py_TapeGradient(
#      72       tape._tape,  # pylint: disable=protected-access
#      73       target,
#
# ~/.pyenv/versions/new_ml_stuff/lib/python3.8/site-packages/tensorflow/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     157       gradient_name_scope += forward_pass_name_scope + "/"
#     158     with ops.name_scope(gradient_name_scope):
# --> 159       return grad_fn(mock_op, *out_grads)
#     160   else:
#     161     return grad_fn(mock_op, *out_grads)
#
# ~/.pyenv/versions/new_ml_stuff/lib/python3.8/site-packages/tensorflow/python/ops/nn_grad.py in _Conv2DGrad(op, grad)
#     579   # in Eager mode.
#     580   return [
# --> 581       gen_nn_ops.conv2d_backprop_input(
#     582           shape_0,
#     583           op.inputs[1],
#
# ~/.pyenv/versions/new_ml_stuff/lib/python3.8/site-packages/tensorflow/python/ops/gen_nn_ops.py in conv2d_backprop_input(input_sizes, filter, out_backprop, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    1238   if tld.is_eager:
#    1239     try:
# -> 1240       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    1241         _ctx, "Conv2DBackpropInput", name, input_sizes, filter, out_backprop,
#    1242         "strides", strides, "use_cudnn_on_gpu", use_cudnn_on_gpu, "padding",
#
# KeyboardInterrupt:

# %%
import os 
import pickle
import visualisation.visualisation as vis

path = 'results_eigenspace'
# with open(os.path.join(path, 'F_eigenval.pkl'), 'rb') as f:
#     F_eigenval = pickle.load(f)
with open(os.path.join(path, 'wp_eigenval.pkl'), 'rb') as f:
    wp_eigenval = pickle.load(f)
with open(os.path.join(path, 'allignment.pkl'), 'rb') as f:
    allignment = pickle.load(f)
with open(os.path.join(path, 'symmetry.pkl'), 'rb') as f:
    symmetry = pickle.load(f)

# %%
vis.symmetry(symmetry)
vis.eigenspace_allignment(allignment, wp_eigenval)
# vis.eigenvalues_F(experiment)
vis.eigenvalues_Wp(wp_eigenval)
