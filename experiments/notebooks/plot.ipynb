# %%
import os 
import sys
sys.path.append('../')
sys.path.append('../..')
import pickle
import visualisation.visualisation as vis
import matplotlib.pyplot as plt

# %% [markdown]
# # Byol experiments

# %%
path = r'C:\Users\tobih\OneDrive\Desktop\Experiments\Byol'
with open(os.path.join(path, 'F_eigenval.pkl'), 'rb') as f:
    F_eigenval = pickle.load(f)
with open(os.path.join(path, 'wp_eigenval.pkl'), 'rb') as f:
    wp_eigenval = pickle.load(f)
with open(os.path.join(path, 'allignment.pkl'), 'rb') as f:
    allignment = pickle.load(f)
with open(os.path.join(path, 'symmetry.pkl'), 'rb') as f:
    symmetry = pickle.load(f)

path = r'C:\Users\tobih\OneDrive\Desktop\Experiments\ByolSymmetric'
with open(os.path.join(path, 'F_eigenval.pkl'), 'rb') as f:
    F_eigenval_reg = pickle.load(f)
with open(os.path.join(path, 'wp_eigenval.pkl'), 'rb') as f:
    wp_eigenval_reg = pickle.load(f)
with open(os.path.join(path, 'allignment.pkl'), 'rb') as f:
    allignment_reg = pickle.load(f)
with open(os.path.join(path, 'symmetry.pkl'), 'rb') as f:
    symmetry_reg = pickle.load(f)

# %%
SMALL_SIZE = 10
MEDIUM_SIZE = 14
BIGGER_SIZE = 18

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
fig, axs = plt.subplots(2, 4)
fig.set_size_inches(25, 10)
vis.eigenvalues_F(F_eigenval, axs[0,0])
vis.eigenvalues_Wp(wp_eigenval, axs[0,1])
vis.eigenspace_allignment(allignment, F_eigenval, axs[0,2])
vis.symmetry(symmetry, axs[0,3])
vis.eigenvalues_F(F_eigenval_reg, axs[1,0], title=False)
vis.eigenvalues_Wp(wp_eigenval_reg, axs[1,1], title=False)
vis.eigenspace_allignment(allignment_reg, F_eigenval, axs[1,2], title=False)
vis.symmetry(symmetry_reg, axs[1,3], title=False)

# %% [markdown]
# # SimSiam Experiments

# %%
path = r'C:\Users\tobih\OneDrive\Desktop\Experiments\SimSiam'
with open(os.path.join(path, 'F_eigenval.pkl'), 'rb') as f:
    F_eigenval = pickle.load(f)
with open(os.path.join(path, 'wp_eigenval.pkl'), 'rb') as f:
    wp_eigenval = pickle.load(f)
with open(os.path.join(path, 'allignment.pkl'), 'rb') as f:
    allignment = pickle.load(f)
with open(os.path.join(path, 'symmetry.pkl'), 'rb') as f:
    symmetry = pickle.load(f)
    path = r'C:\Users\tobih\OneDrive\Desktop\Experiments\SimSiamSymmetric'
with open(os.path.join(path, 'F_eigenval.pkl'), 'rb') as f:
    F_eigenval_reg = pickle.load(f)
with open(os.path.join(path, 'wp_eigenval.pkl'), 'rb') as f:
    wp_eigenval_reg = pickle.load(f)
with open(os.path.join(path, 'allignment.pkl'), 'rb') as f:
    allignment_reg = pickle.load(f)
with open(os.path.join(path, 'symmetry.pkl'), 'rb') as f:
    symmetry_reg = pickle.load(f)

# %%
fig, axs = plt.subplots(2, 4)
fig.set_size_inches(25, 10)
vis.eigenvalues_F(F_eigenval, axs[0,0])
vis.eigenvalues_Wp(wp_eigenval, axs[0,1])
vis.eigenspace_allignment(allignment, F_eigenval, axs[0,2])
vis.symmetry(symmetry, axs[0,3])
vis.eigenvalues_F(F_eigenval_reg, axs[1,0], title=False, log=False)
vis.eigenvalues_Wp(wp_eigenval_reg, axs[1,1], title=False)
vis.eigenspace_allignment(allignment_reg, F_eigenval, axs[1,2], title=False)
vis.symmetry(symmetry_reg, axs[1,3], title=False)

# %% [markdown]
# # stable symmetric SimSiam

# %%
SMALL_SIZE = 10
MEDIUM_SIZE = 14
BIGGER_SIZE = 18

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
path = r'C:\Users\tobih\OneDrive\Desktop\Experiments\SimSiamsymmetric_pred'
with open(os.path.join(path, 'F_eigenval.pkl'), 'rb') as f:
    F_eigenval = pickle.load(f)
with open(os.path.join(path, 'wp_eigenval.pkl'), 'rb') as f:
    wp_eigenval = pickle.load(f)
with open(os.path.join(path, 'allignment.pkl'), 'rb') as f:
    allignment = pickle.load(f)
with open(os.path.join(path, 'symmetry.pkl'), 'rb') as f:
    symmetry = pickle.load(f)

# %%
fig, axs = plt.subplots(1, 4)
fig.set_size_inches(25, 4)
vis.eigenvalues_F(F_eigenval, axs[0])
vis.eigenvalues_Wp(wp_eigenval, axs[1])
vis.eigenspace_allignment(allignment, F_eigenval, axs[2])
vis.symmetry(symmetry, axs[3])

# %% [markdown]
# # Performance results

# %%
import seaborn as sns
import pandas as pd
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data = {'EMA':['EMA', 'EMA', 'EMA', 'no EMA', 'no EMA', 'no EMA'],
        'Accuracy': [84.7, 84.6, 83.3, 78.6, 78.3, 77.8],
        'Model':['DirectPred', 'DirectCopy', 'SGD baseline', 'DirectPred', 'DirectCopy', 'SGD baseline']}
data_df = pd.DataFrame.from_dict(data)
data_df
# Out:
#       EMA  Accuracy         Model
# 0     EMA      84.7    DirectPred
# 1     EMA      84.6    DirectCopy
# 2     EMA      83.3  SGD baseline
# 3  no EMA      78.6    DirectPred
# 4  no EMA      78.3    DirectCopy
# 5  no EMA      77.8  SGD baseline

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.set_theme(style="whitegrid")
ax = sns.barplot(x="EMA", y="Accuracy", hue="Model", data=data_df)
ax.axes.set_title('Accuracies of one layer predictor models', fontsize=25)
ax.set_xlabel('use of EMA', fontsize=20)
ax.set_ylabel('Accuracy', fontsize=20)
ax.tick_params(labelsize=15)
ax.set(ylim=(70, None))
# Out:
# [(70.0, 88.935)]
